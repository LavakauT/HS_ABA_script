# %%
import os
import pandas as pd

from tfcomb import CombObj
import tfcomb.objects
import tfcomb.annotation

pd.set_option("display.max_columns", 50)

# %%
# list treatment folder
directory = '/Users/user/Desktop/tomato_atac/tfcomb2/bed/similar'
gff_path = '/Users/user/Desktop/tomato_atac'
directory_contents = [name for name in os.listdir(directory) if os.path.isdir(os.path.join(directory, name))]
print(directory_contents)
# Out:
# ['similar_ATAC_M82_6h_vs_ATAC_M82_0h_proximal_up', 'similar_ATAC_M82_1h_vs_ATAC_M82_0h_proximal_down', 'similar_ATAC_M82_1h_vs_ATAC_M82_0h_distal_down', 'similar_ATAC_M82_6h_vs_ATAC_M82_0h_proximal_down', 'similar_ATAC_M82_1h_vs_ATAC_M82_0h_proximal_up', 'similar_ATAC_M82_6h_vs_ATAC_M82_0h_distal_down', 'similar_ATAC_M82_6h_vs_ATAC_M82_0h_distal_up', 'similar_ATAC_M82_1h_vs_ATAC_M82_0h_distal_up']

# %%
# annotate binding sites to genes
locations = pd.DataFrame()

# custom: annotation genes
custom_config = {"queries": [{"distance": [1500, 500], 
    "feature_anchor": "start", 
    "feature": "transcript"}],
    "priority": True, 
    "show_attributes": "all"}

# the transcript file was made by following code:
# gffread Slycopersicum_796_ITAG5.0.gene.gff3 -T -o Slycopersicum_796_ITAG5.0.gene.gtf
# awk '$3 == "transcript"' Slycopersicum_796_ITAG5.0.gene.gtf > Slycopersicum_796_ITAG5.0.sorted_transcript.gtf


for dir in directory_contents:
    file = os.path.join(directory, dir, 'selected_sig', dir + '.pkl')
    print(file)
    # extract base name
    bn = os.path.splitext(file)[0]

    ###### LAOD FILES FROM PKL ######
    C = tfcomb.CombObj().from_pickle(os.path.join(file))
    
    # roughly show the data
    C.rules.head(20)

    # pass all the rules
    table = C.rules
    ############

    ###### GET LOCATION TABLE ######
    # get location table
    for index, row in table.iterrows():
        tf1 = row['TF1']
        tf2 = row['TF2']
        print(f'Processing: TF1={tf1}, TF2={tf2}')

        location = C.get_pair_locations((tf1, tf2)).as_table()
        locations = pd.concat([locations, location], axis = 0)

    locations.reset_index(drop = True, inplace = True)
    print(locations)
    if not locations.empty:
        print("location table has rows and keep going.")
    else:
        print("location table is empty. stop!")
        # Skip to the next iteration if the DataFrame is not empty
        continue
    ############
    
    
    ###### ANNOTATION ######
    # annotate genes
    annotated = tfcomb.annotation.annotate_regions(locations, gtf = os.path.join(gff_path, 'Slycopersicum_796_ITAG5.0.sorted_transcript.gtf'), config = custom_config)
    
    if annotated is None:
        print("annotated table is empty. stop!")
        # Skip to the next iteration if the DataFrame is not empty
        continue
    
    # export table
    print("file is exported to " + os.path.join(directory, bn + '_sites.txt'))
    annotated.to_csv(os.path.join(directory, bn + '_sites.txt'),
                sep='\t', index=False, header=True)
    ############
    print('Finished: ' + bn + '!')
print('Finished all!')
# Out:
# /Users/user/Desktop/tomato_atac/tfcomb2/bed/similar/similar_ATAC_M82_6h_vs_ATAC_M82_0h_proximal_up/selected_sig/similar_ATAC_M82_6h_vs_ATAC_M82_0h_proximal_up.pkl
# Empty DataFrame
# Columns: []
# Index: []
# location table is empty. stop!
# /Users/user/Desktop/tomato_atac/tfcomb2/bed/similar/similar_ATAC_M82_1h_vs_ATAC_M82_0h_proximal_down/selected_sig/similar_ATAC_M82_1h_vs_ATAC_M82_0h_proximal_down.pkl
# Processing: TF1=C2_MYBrelated_2, TF2=C3_AP2EREBP_66
# INFO: Setting up binding sites for counting
# Processing: TF1=C3_AP2EREBP_15, TF2=C3_AP2EREBP_23
# Processing: TF1=C3_AP2EREBP_23, TF2=C3_Trihelix_25
# Processing: TF1=C3_AP2EREBP_23, TF2=C3_Trihelix_26
#    site1_chrom  site1_start  site1_end       site1_name  site1_score
# 0            1     89978391   89978400  C2_MYBrelated_2     10.80361  \
# 1            7       654144     654152   C3_AP2EREBP_23      6.70273
# 2            7       654144     654152   C3_AP2EREBP_23      6.70273
# 3            7       654144     654152   C3_AP2EREBP_23      6.70273
#
#   site1_strand  site2_chrom  site2_start  site2_end      site2_name
# 0            +            1     89978404   89978411  C3_AP2EREBP_66  \
# 1            +            7       654167     654174  C3_AP2EREBP_15
# 2            +            7       654167     654174  C3_Trihelix_25
# 3            +            7       654167     654175  C3_Trihelix_26
#
#    site2_score site2_strand  site_distance site_orientation
# 0     10.75965            -              4       convergent
# 1     11.87604            -             15       convergent
# 2      5.56435            +             15          TF1-TF2
# 3      6.70273            +             15          TF1-TF2
# location table has rows and keep going.
# WARNING: No annotations found for given config. Return type is None.
# annotated table is empty. stop!
# /Users/user/Desktop/tomato_atac/tfcomb2/bed/similar/similar_ATAC_M82_1h_vs_ATAC_M82_0h_distal_down/selected_sig/similar_ATAC_M82_1h_vs_ATAC_M82_0h_distal_down.pkl
#    site1_chrom  site1_start  site1_end       site1_name  site1_score
# 0            1     89978391   89978400  C2_MYBrelated_2     10.80361  \
# 1            7       654144     654152   C3_AP2EREBP_23      6.70273
# 2            7       654144     654152   C3_AP2EREBP_23      6.70273
# 3            7       654144     654152   C3_AP2EREBP_23      6.70273
#
#   site1_strand  site2_chrom  site2_start  site2_end      site2_name
# 0            +            1     89978404   89978411  C3_AP2EREBP_66  \
# 1            +            7       654167     654174  C3_AP2EREBP_15
# 2            +            7       654167     654174  C3_Trihelix_25
# 3            +            7       654167     654175  C3_Trihelix_26
#
#    site2_score site2_strand  site_distance site_orientation
# 0     10.75965            -              4       convergent
# 1     11.87604            -             15       convergent
# 2      5.56435            +             15          TF1-TF2
# 3      6.70273            +             15          TF1-TF2
# location table has rows and keep going.
# WARNING: No annotations found for given config. Return type is None.
# annotated table is empty. stop!
# /Users/user/Desktop/tomato_atac/tfcomb2/bed/similar/similar_ATAC_M82_6h_vs_ATAC_M82_0h_proximal_down/selected_sig/similar_ATAC_M82_6h_vs_ATAC_M82_0h_proximal_down.pkl
#    site1_chrom  site1_start  site1_end       site1_name  site1_score
# 0            1     89978391   89978400  C2_MYBrelated_2     10.80361  \
# 1            7       654144     654152   C3_AP2EREBP_23      6.70273
# 2            7       654144     654152   C3_AP2EREBP_23      6.70273
# 3            7       654144     654152   C3_AP2EREBP_23      6.70273
#
#   site1_strand  site2_chrom  site2_start  site2_end      site2_name
# 0            +            1     89978404   89978411  C3_AP2EREBP_66  \
# 1            +            7       654167     654174  C3_AP2EREBP_15
# 2            +            7       654167     654174  C3_Trihelix_25
# 3            +            7       654167     654175  C3_Trihelix_26
#
#    site2_score site2_strand  site_distance site_orientation
# 0     10.75965            -              4       convergent
# 1     11.87604            -             15       convergent
# 2      5.56435            +             15          TF1-TF2
# 3      6.70273            +             15          TF1-TF2
# location table has rows and keep going.
# WARNING: No annotations found for given config. Return type is None.
# annotated table is empty. stop!
# /Users/user/Desktop/tomato_atac/tfcomb2/bed/similar/similar_ATAC_M82_1h_vs_ATAC_M82_0h_proximal_up/selected_sig/similar_ATAC_M82_1h_vs_ATAC_M82_0h_proximal_up.pkl
#    site1_chrom  site1_start  site1_end       site1_name  site1_score
# 0            1     89978391   89978400  C2_MYBrelated_2     10.80361  \
# 1            7       654144     654152   C3_AP2EREBP_23      6.70273
# 2            7       654144     654152   C3_AP2EREBP_23      6.70273
# 3            7       654144     654152   C3_AP2EREBP_23      6.70273
#
#   site1_strand  site2_chrom  site2_start  site2_end      site2_name
# 0            +            1     89978404   89978411  C3_AP2EREBP_66  \
# 1            +            7       654167     654174  C3_AP2EREBP_15
# 2            +            7       654167     654174  C3_Trihelix_25
# 3            +            7       654167     654175  C3_Trihelix_26
#
#    site2_score site2_strand  site_distance site_orientation
# 0     10.75965            -              4       convergent
# 1     11.87604            -             15       convergent
# 2      5.56435            +             15          TF1-TF2
# 3      6.70273            +             15          TF1-TF2
# location table has rows and keep going.
# WARNING: No annotations found for given config. Return type is None.
# annotated table is empty. stop!
# /Users/user/Desktop/tomato_atac/tfcomb2/bed/similar/similar_ATAC_M82_6h_vs_ATAC_M82_0h_distal_down/selected_sig/similar_ATAC_M82_6h_vs_ATAC_M82_0h_distal_down.pkl
# Processing: TF1=C3_ND_2, TF2=C4_ND_3
# INFO: Setting up binding sites for counting
# Processing: TF1=C3_C2C2gata_3, TF2=C3_ND_2
# Processing: TF1=C3_C2C2gata_1-C4_C2C2gata_1, TF2=C3_C2C2gata_3
# Processing: TF1=C3_C2C2gata_1-C4_C2C2gata_1, TF2=C3_ND_2
# Processing: TF1=C3_C2C2gata_3, TF2=C4_ND_3
# Processing: TF1=C3_C2C2gata_1-C4_C2C2gata_1, TF2=C4_ND_3
# Processing: TF1=C3_C2C2gata_1-C4_C2C2gata_1, TF2=C3_C2H2_26
# Processing: TF1=C3_C2C2gata_3, TF2=C3_C2H2_26
# Processing: TF1=C3_ND_2, TF2=C3_ND_2
#       site1_chrom  site1_start  site1_end       site1_name  site1_score
# 0               1     89978391   89978400  C2_MYBrelated_2     10.80361  \
# 1               7       654144     654152   C3_AP2EREBP_23      6.70273
# 2               7       654144     654152   C3_AP2EREBP_23      6.70273
# 3               7       654144     654152   C3_AP2EREBP_23      6.70273
# 4               7     19778611   19778617          C3_ND_2      8.63046
# ...           ...          ...        ...              ...          ...
# 1874            7     19779493   19779499          C3_ND_2      8.63046
# 1875            7     19779493   19779499          C3_ND_2      8.63046
# 1876            7     19779508   19779514          C3_ND_2      8.63046
# 1877            7     19779508   19779514          C3_ND_2      8.63046
# 1878            7     19779514   19779520          C3_ND_2      8.63046
#
#      site1_strand  site2_chrom  site2_start  site2_end      site2_name
# 0               +            1     89978404   89978411  C3_AP2EREBP_66  \
# 1               +            7       654167     654174  C3_AP2EREBP_15
# 2               +            7       654167     654174  C3_Trihelix_25
# 3               +            7       654167     654175  C3_Trihelix_26
# 4               +            7     19778694   19778700         C4_ND_3
# ...           ...          ...          ...        ...             ...
# 1874            +            7     19779514   19779520         C3_ND_2
# 1875            +            7     19779526   19779532         C3_ND_2
# 1876            +            7     19779514   19779520         C3_ND_2
# 1877            +            7     19779526   19779532         C3_ND_2
# 1878            +            7     19779526   19779532         C3_ND_2
#
#       site2_score site2_strand  site_distance site_orientation
# 0        10.75965            -              4       convergent
# 1        11.87604            -             15       convergent
# 2         5.56435            +             15          TF1-TF2
# 3         6.70273            +             15          TF1-TF2
# 4         8.63046            +             77          TF1-TF2
# ...           ...          ...            ...              ...
# 1874      8.63046            +             15          TF1-TF2
# 1875      8.63046            +             27          TF1-TF2
# 1876      8.63046            +              0          TF1-TF2
# 1877      8.63046            +             12          TF1-TF2
# 1878      8.63046            +              6          TF1-TF2
#
# [1879 rows x 14 columns]
# location table has rows and keep going.
# WARNING: No annotations found for given config. Return type is None.
# annotated table is empty. stop!
# /Users/user/Desktop/tomato_atac/tfcomb2/bed/similar/similar_ATAC_M82_6h_vs_ATAC_M82_0h_distal_up/selected_sig/similar_ATAC_M82_6h_vs_ATAC_M82_0h_distal_up.pkl
# Processing: TF1=C2_AP2EREBP_3-C3_AP2EREBP_24, TF2=C3_AP2EREBP_22
# INFO: Setting up binding sites for counting
#       site1_chrom  site1_start  site1_end                    site1_name
# 0               1     89978391   89978400               C2_MYBrelated_2  \
# 1               7       654144     654152                C3_AP2EREBP_23
# 2               7       654144     654152                C3_AP2EREBP_23
# 3               7       654144     654152                C3_AP2EREBP_23
# 4               7     19778611   19778617                       C3_ND_2
# ...           ...          ...        ...                           ...
# 2804            9     69089431   69089437  C2_AP2EREBP_3-C3_AP2EREBP_24
# 2805            9     69089431   69089437                C3_AP2EREBP_22
# 2806            9     69089431   69089437                C3_AP2EREBP_22
# 2807            9     69089465   69089471  C2_AP2EREBP_3-C3_AP2EREBP_24
# 2808            9     69089465   69089471                C3_AP2EREBP_22
#
#       site1_score site1_strand  site2_chrom  site2_start  site2_end
# 0        10.80361            +            1     89978404   89978411  \
# 1         6.70273            +            7       654167     654174
# 2         6.70273            +            7       654167     654174
# 3         6.70273            +            7       654167     654175
# 4         8.63046            +            7     19778694   19778700
# ...           ...          ...          ...          ...        ...
# 2804      4.31576            -            9     69089507   69089513
# 2805      4.31576            -            9     69089465   69089471
# 2806      4.31576            -            9     69089507   69089513
# 2807      4.31576            -            9     69089507   69089513
# 2808     10.02152            -            9     69089507   69089513
#
#                         site2_name  site2_score site2_strand  site_distance
# 0                   C3_AP2EREBP_66     10.75965            -              4  \
# 1                   C3_AP2EREBP_15     11.87604            -             15
# 2                   C3_Trihelix_25      5.56435            +             15
# 3                   C3_Trihelix_26      6.70273            +             15
# 4                          C4_ND_3      8.63046            +             77
# ...                            ...          ...          ...            ...
# 2804                C3_AP2EREBP_22     10.02152            -             70
# 2805  C2_AP2EREBP_3-C3_AP2EREBP_24      4.31576            -             28
# 2806  C2_AP2EREBP_3-C3_AP2EREBP_24      4.31576            -             70
# 2807                C3_AP2EREBP_22     10.02152            -             36
# 2808  C2_AP2EREBP_3-C3_AP2EREBP_24      4.31576            -             36
#
#      site_orientation
# 0          convergent
# 1          convergent
# 2             TF1-TF2
# 3             TF1-TF2
# 4             TF1-TF2
# ...               ...
# 2804          TF2-TF1
# 2805          TF2-TF1
# 2806          TF2-TF1
# 2807          TF2-TF1
# 2808          TF2-TF1
#
# [2809 rows x 14 columns]
# location table has rows and keep going.
# WARNING: No annotations found for given config. Return type is None.
# annotated table is empty. stop!
# /Users/user/Desktop/tomato_atac/tfcomb2/bed/similar/similar_ATAC_M82_1h_vs_ATAC_M82_0h_distal_up/selected_sig/similar_ATAC_M82_1h_vs_ATAC_M82_0h_distal_up.pkl
# Processing: TF1=C3_ABI3VP1_7, TF2=C3_C2H2_16
# INFO: Setting up binding sites for counting
# Processing: TF1=C2_HSF_4, TF2=C3_G2like_3
# Processing: TF1=C2_HSF_1, TF2=C3_G2like_3
# Processing: TF1=C2_bZIP_3-C3_bZIP_6-C4_bZIP_1, TF2=C4_C2C2gata_5
# Processing: TF1=C2_GeBP_2, TF2=C3_G2like_3
# Processing: TF1=C1_C3H_3, TF2=C3_ABI3VP1_7
# Processing: TF1=C3_C2C2gata_7, TF2=C3_bZIP_15
# Processing: TF1=C2_C2C2gata_15, TF2=C3_C2H2_26
# Processing: TF1=C2_HSF_1, TF2=C2_HSF_4
#       site1_chrom  site1_start  site1_end       site1_name  site1_score
# 0               1     89978391   89978400  C2_MYBrelated_2     10.80361  \
# 1               7       654144     654152   C3_AP2EREBP_23      6.70273
# 2               7       654144     654152   C3_AP2EREBP_23      6.70273
# 3               7       654144     654152   C3_AP2EREBP_23      6.70273
# 4               7     19778611   19778617          C3_ND_2      8.63046
# ...           ...          ...        ...              ...          ...
# 2997            9     63436729   63436739         C2_HSF_4      1.58151
# 2998            9     63436729   63436740         C2_HSF_1      2.67215
# 2999            9     63436729   63436740         C2_HSF_1      2.67215
# 3000            9     63436784   63436795         C2_HSF_1      2.67215
# 3001            9     63436785   63436795         C2_HSF_4      1.58151
#
#      site1_strand  site2_chrom  site2_start  site2_end      site2_name
# 0               +            1     89978404   89978411  C3_AP2EREBP_66  \
# 1               +            7       654167     654174  C3_AP2EREBP_15
# 2               +            7       654167     654174  C3_Trihelix_25
# 3               +            7       654167     654175  C3_Trihelix_26
# 4               +            7     19778694   19778700         C4_ND_3
# ...           ...          ...          ...        ...             ...
# 2997            +            9     63436799   63436810        C2_HSF_1
# 2998            +            9     63436785   63436795        C2_HSF_4
# 2999            +            9     63436800   63436810        C2_HSF_4
# 3000            -            9     63436800   63436810        C2_HSF_4
# 3001            -            9     63436799   63436810        C2_HSF_1
#
#       site2_score site2_strand  site_distance site_orientation
# 0        10.75965            -              4       convergent
# 1        11.87604            -             15       convergent
# 2         5.56435            +             15          TF1-TF2
# 3         6.70273            +             15          TF1-TF2
# 4         8.63046            +             77          TF1-TF2
# ...           ...          ...            ...              ...
# 2997      8.37792            -             60       convergent
# 2998      1.58151            -             45       convergent
# 2999      7.28727            -             60       convergent
# 3000      7.28727            -              5          TF2-TF1
# 3001      8.37792            -              4          TF2-TF1
#
# [3002 rows x 14 columns]
# location table has rows and keep going.
# file is exported to /Users/user/Desktop/tomato_atac/tfcomb2/bed/similar/similar_ATAC_M82_1h_vs_ATAC_M82_0h_distal_up/selected_sig/similar_ATAC_M82_1h_vs_ATAC_M82_0h_distal_up_sites.txt
# Finished: /Users/user/Desktop/tomato_atac/tfcomb2/bed/similar/similar_ATAC_M82_1h_vs_ATAC_M82_0h_distal_up/selected_sig/similar_ATAC_M82_1h_vs_ATAC_M82_0h_distal_up!
# Finished all!
